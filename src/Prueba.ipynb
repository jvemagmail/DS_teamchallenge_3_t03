# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from scipy.stats import pearsonr
from scipy.stats import f_oneway
from scipy import stats
from Toolbox import *

# %%
df = pd.read_csv("../data/titanic.csv")

# %%
describe_df(df)
# Out:
#                 survived  pclass       sex       age     sibsp     parch  \
# Tipo               int64   int64    object   float64     int64     int64
# % Nulos              0.0     0.0       0.0  19.86532       0.0       0.0
# Valores únicos         2       3         2        88         7         7
# % Cardinalidad  0.224467  0.3367  0.224467  9.876543  0.785634  0.785634
#
#                      fare  embarked   class     who adult_male       deck  \
# Tipo              float64    object  object  object       bool     object
# % Nulos               0.0  0.224467     0.0     0.0        0.0  77.216611
# Valores únicos        248         3       3       3          2          7
# % Cardinalidad  27.833895    0.3367  0.3367  0.3367   0.224467   0.785634
#
#                embark_town     alive     alone
# Tipo                object    object      bool
# % Nulos           0.224467       0.0       0.0
# Valores únicos           3         2         2
# ...

# %%
tipifica_variables(df, 7, 7)
# Out:
#    nombre_variable      tipo_sugerido
# 0         survived            Binaria
# 1           pclass         Categórica
# 2              sex            Binaria
# 3              age  Numerica Continua
# 4            sibsp  Numerica Discreta
# 5            parch  Numerica Discreta
# 6             fare  Numerica Continua
# 7         embarked         Categórica
# 8            class         Categórica
# 9              who         Categórica
# 10      adult_male            Binaria
# 11            deck  Numerica Discreta
# 12     embark_town         Categórica
# 13           alive            Binaria
# 14           alone            Binaria

# %%
get_features_num_regression(df, 'age', 0.1)
# Out:
# ['pclass', 'sibsp', 'parch']

# %%
get_features_num_regression(df, 'fare', 0.1)
# Out:
# ['survived', 'pclass', 'sibsp', 'parch']

# %%
# df, target_col="", columns=[], umbral_corr=0, pvalue=None):
plot_features_num_regression(df, 'survived')
# Out:
# ['pclass', 'age', 'sibsp', 'parch', 'fare']

# %%
get_features_cat_regression(df, 'fare', 0.5, False)
# Out:
# ['sex',
#  'embarked',
#  'class',
#  'who',
#  'adult_male',
#  'deck',
#  'embark_town',
#  'alive',
#  'alone']

# %%
get_features_cat_regression(df, 'age', 0.5, False)
# Out:
# ['sex', 'class', 'who', 'adult_male', 'deck', 'alive', 'alone']

# %%
#plot_features_cat_regression(df, target_col="", columns=[], pvalue=0.05, with_individual_plot=False):
plot_features_cat_regression(df, 'age', pvalue=0.5, with_individual_plot=False)
# Out:
# ['sex', 'class', 'who', 'deck', 'alive']
